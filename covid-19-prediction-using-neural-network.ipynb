# %% [markdown]
# <a href="https://www.kaggle.com/code/shiv28/covid-19-prediction-using-neural-network?scriptVersionId=96131332" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## **Covid-19 prediction using Neural Network**

# %% [markdown]
# ## Abstract

# %% [markdown]
# This notebook is devoted to predicting the COVID-19 spread dynamics in the world using neural networks of different structures. We will see how to make predictions based on linear regression, back propagation  and long short-term memory neural networks

# %% [markdown]
# ## Introduction

# %% [markdown]
# Today there is a lot of open data about the spread of COVID-19 in the world. However, few tools are presented to predict  these processes.
#
# 3 different mathematical models for the forecast calculation will taken.
#
# To do this, the division of the DataSet into training and test sets will be demonstrated, normalize data and make preliminary analysis.
#
# It will be shown how to build models and DataSets for using 2 different neural networks.
#
# The next step is to compare the accuracy and adequacy of the obtained models.

# %% [markdown]
# ## Steps or Stages

# %% [markdown]
# It consists of four stages:
#
# *   Download and preliminary analysis of data
# *   Linear Regression
# *   Back Propagation NN
# *   Long Short-Term Memory - LSTM

# %% [markdown]
# In first stage we pre-prepare data for analysis:
#
# *   change the data types of columns
# *   rows filtering
# *   elimination of missing data
# *   DataSet transformation
# *   data normalization
#
# During the next steps, we will demonstrate 3 different models .

# %% [markdown]
# ## Prerequisites
#
# *   Python
# *   Pandas
# *   Statistics
# *   NumPy
# *   Matplotlib
# *   Keras
# *   Scikit-Learn

# %% [markdown]
# ## Objectives

# %% [markdown]
# ## Required libraries Importing

# %% [markdown]
# Some libraries should be imported .

# %%
import pandas as pd
import numpy as np

# %%
covid_word = pd.read_csv('../input/covidowid/owid-covid-data.csv')
covid_word
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 187796      ZWE    Africa     Zimbabwe  2022-05-15     249206.0        0.0
# 187797      ZWE    Africa     Zimbabwe  2022-05-16     249431.0      225.0
# 187798      ZWE    Africa     Zimbabwe  2022-05-17     249748.0      317.0
# 187799      ZWE    Africa     Zimbabwe  2022-05-18     250007.0      259.0
# 187800      ZWE    Africa     Zimbabwe  2022-05-19     250206.0      199.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 187796             122.000        5482.0         0.0                0.857
# 187797             127.857        5484.0         2.0                0.714
# 187798             158.000        5484.0         0.0                0.429
# 187799             195.000        5486.0         2.0                0.714
# 187800             180.429        5487.0         1.0                0.857
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 0       ...             NaN           NaN                  37.746
# 1       ...             NaN           NaN                  37.746
# 2       ...             NaN           NaN                  37.746
# 3       ...             NaN           NaN                  37.746
# 4       ...             NaN           NaN                  37.746
# ...     ...             ...           ...                     ...
# 187796  ...             1.6          30.7                  36.791
# 187797  ...             1.6          30.7                  36.791
# 187798  ...             1.6          30.7                  36.791
# 187799  ...             1.6          30.7                  36.791
# 187800  ...             1.6          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              0.5            64.83                    0.511
# 1                              0.5            64.83                    0.511
# 2                              0.5            64.83                    0.511
# 3                              0.5            64.83                    0.511
# 4                              0.5            64.83                    0.511
# ...                            ...              ...                      ...
# 187796                         1.7            61.49                    0.571
# 187797                         1.7            61.49                    0.571
# 187798                         1.7            61.49                    0.571
# 187799                         1.7            61.49                    0.571
# 187800                         1.7            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 187796                                   NaN                          NaN
# 187797                                   NaN                          NaN
# 187798                                   NaN                          NaN
# 187799                                   NaN                          NaN
# 187800                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 187796               NaN                                      NaN
# 187797               NaN                                      NaN
# 187798               NaN                                      NaN
# 187799               NaN                                      NaN
# 187800               NaN                                      NaN
#
# [187801 rows x 67 columns]

# %% [markdown]
# Let's study our DataSet. As you can see, it consist of 159321 rows × 67 columns. There is some missing data are observed in the DataSet. We should be sure that Python recognized types of data correctly.

# %%
covid_word.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187801 entries, 0 to 187800
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    187801 non-null  object
#  1   continent                                   176870 non-null  object
#  2   location                                    187801 non-null  object
#  3   date                                        187801 non-null  object
#  4   total_cases                                 180399 non-null  float64
#  5   new_cases                                   180190 non-null  float64
#  6   new_cases_smoothed                          179016 non-null  float64
#  7   total_deaths                                162023 non-null  float64
#  8   new_deaths                                  162021 non-null  float64
#  9   new_deaths_smoothed                         160860 non-null  float64
#  10  total_cases_per_million                     179566 non-null  float64
#  11  new_cases_per_million                       179357 non-null  float64
#  12  new_cases_smoothed_per_million              178188 non-null  float64
#  13  total_deaths_per_million                    161203 non-null  float64
#  14  new_deaths_per_million                      161201 non-null  float64
#  15  new_deaths_smoothed_per_million             160045 non-null  float64
#  16  reproduction_rate                           140328 non-null  float64
#  17  icu_patients                                24355 non-null   float64
#  18  icu_patients_per_million                    24355 non-null   float64
#  19  hosp_patients                               25613 non-null   float64
#  20  hosp_patients_per_million                   25613 non-null   float64
#  21  weekly_icu_admissions                       6073 non-null    float64
#  22  weekly_icu_admissions_per_million           6073 non-null    float64
#  23  weekly_hosp_admissions                      12120 non-null   float64
#  24  weekly_hosp_admissions_per_million          12120 non-null   float64
#  25  total_tests                                 76651 non-null   float64
#  26  new_tests                                   73618 non-null   float64
#  27  total_tests_per_thousand                    76651 non-null   float64
#  28  new_tests_per_thousand                      73618 non-null   float64
#  29  new_tests_smoothed                          99087 non-null   float64
#  30  new_tests_smoothed_per_thousand             99087 non-null   float64
#  31  positive_rate                               91397 non-null   float64
#  32  tests_per_case                              89869 non-null   float64
#  33  tests_units                                 101893 non-null  object
#  34  total_vaccinations                          50985 non-null   float64
#  35  people_vaccinated                           48558 non-null   float64
#  36  people_fully_vaccinated                     46007 non-null   float64
#  37  total_boosters                              23182 non-null   float64
#  38  new_vaccinations                            41701 non-null   float64
#  39  new_vaccinations_smoothed                   100393 non-null  float64
#  40  total_vaccinations_per_hundred              50985 non-null   float64
#  41  people_vaccinated_per_hundred               48558 non-null   float64
#  42  people_fully_vaccinated_per_hundred         46007 non-null   float64
#  43  total_boosters_per_hundred                  23182 non-null   float64
#  44  new_vaccinations_smoothed_per_million       100393 non-null  float64
#  45  new_people_vaccinated_smoothed              99375 non-null   float64
#  46  new_people_vaccinated_smoothed_per_hundred  99375 non-null   float64
#  47  stringency_index                            146156 non-null  float64
#  48  population                                  186651 non-null  float64
#  49  population_density                          167345 non-null  float64
#  50  median_age                                  155139 non-null  float64
#  51  aged_65_older                               153494 non-null  float64
#  52  aged_70_older                               154325 non-null  float64
#  53  gdp_per_capita                              154268 non-null  float64
#  54  extreme_poverty                             100750 non-null  float64
#  55  cardiovasc_death_rate                       154794 non-null  float64
#  56  diabetes_prevalence                         162353 non-null  float64
#  57  female_smokers                              117078 non-null  float64
#  58  male_smokers                                115473 non-null  float64
#  59  handwashing_facilities                      76052 non-null   float64
#  60  hospital_beds_per_thousand                  137349 non-null  float64
#  61  life_expectancy                             175620 non-null  float64
#  62  human_development_index                     150786 non-null  float64
#  63  excess_mortality_cumulative_absolute        6460 non-null    float64
#  64  excess_mortality_cumulative                 6460 non-null    float64
#  65  excess_mortality                            6460 non-null    float64
#  66  excess_mortality_cumulative_per_million     6460 non-null    float64
# dtypes: float64(62), object(5)
# memory usage: 96.0+ MB

# %% [markdown]
# As you can see, 66 columns of COVID-19 data were recognized correctly (float64). First 4 columns and tests_units were recognized as objects. Let's investigate them:

# %%
fields = ['iso_code', 'continent', 'location', 'tests_units']
covid_word[fields]
# Out:
#        iso_code continent     location      tests_units
# 0           AFG      Asia  Afghanistan              NaN
# 1           AFG      Asia  Afghanistan              NaN
# 2           AFG      Asia  Afghanistan              NaN
# 3           AFG      Asia  Afghanistan              NaN
# 4           AFG      Asia  Afghanistan              NaN
# ...         ...       ...          ...              ...
# 187796      ZWE    Africa     Zimbabwe  tests performed
# 187797      ZWE    Africa     Zimbabwe  tests performed
# 187798      ZWE    Africa     Zimbabwe  tests performed
# 187799      ZWE    Africa     Zimbabwe  tests performed
# 187800      ZWE    Africa     Zimbabwe              NaN
#
# [187801 rows x 4 columns]

# %% [markdown]
# Let's show information about the field date.

# %%
covid_word['date']
# Out:
# 0         2020-02-24
# 1         2020-02-25
# 2         2020-02-26
# 3         2020-02-27
# 4         2020-02-28
#              ...
# 187796    2022-05-15
# 187797    2022-05-16
# 187798    2022-05-17
# 187799    2022-05-18
# 187800    2022-05-19
# Name: date, Length: 187801, dtype: object

# %% [markdown]
# ### Сhange the data types of columns

# %% [markdown]
# As you can see, the columns: 'iso_code', 'continent', 'location', 'tests_units' have many repetitions and should be assigned to categorical fields **pandas.astype()**.
#
# The field 'data' should be converted into DataTime type **pandas.to_datetime**
# To see the results we can use **pandas.describe()**.

# %%
fields = ['iso_code', 'continent', 'location', 'tests_units']
covid_word[fields] =covid_word[fields].astype('category')
covid_word.loc[:, 'date'] = pd.to_datetime(covid_word['date'])
covid_word[fields].describe()
# Out:
#        iso_code continent location      tests_units
# count    187801    176870   187801           101893
# unique      244         6      244                4
# top         ARG    Africa   Mexico  tests performed
# freq        870     43543      870            75951

# %% [markdown]
# ### Rows filtering

# %% [markdown]
# As we can see, the DataSet contains information about 6 continents and 238 countries.
# The field 'tests_units' consist of 4 categories. To show a list of countries, we can use **pandas.Series.cat.categories**.

# %%
covid_word['location'].cat.categories
# Out:
# Index(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia',
#        ...
#        'Vanuatu', 'Vatican', 'Venezuela', 'Vietnam', 'Wallis and Futuna',
#        'Western Sahara', 'World', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', length=244)

# %% [markdown]
# Let's investigate the dynamics of new cases of COVID-19 for a separate country. We will use India for saving models and further forecast. You can use your country. Let's use a pandas filter to do this.

# %%
covid_word.index = covid_word['date']
c_covid = covid_word[covid_word['location'] == "India"]
c_covid
# Out:
#            iso_code continent location       date  total_cases  new_cases  \
# date
# 2020-01-30      IND      Asia    India 2020-01-30          1.0        1.0
# 2020-01-31      IND      Asia    India 2020-01-31          1.0        0.0
# 2020-02-01      IND      Asia    India 2020-02-01          1.0        0.0
# 2020-02-02      IND      Asia    India 2020-02-02          2.0        1.0
# 2020-02-03      IND      Asia    India 2020-02-03          3.0        1.0
# ...             ...       ...      ...        ...          ...        ...
# 2022-05-15      IND      Asia    India 2022-05-15   43123801.0     2202.0
# 2022-05-16      IND      Asia    India 2022-05-16   43125370.0     1569.0
# 2022-05-17      IND      Asia    India 2022-05-17   43127199.0     1829.0
# 2022-05-18      IND      Asia    India 2022-05-18   43129563.0     2364.0
# 2022-05-19      IND      Asia    India 2022-05-19   43131822.0     2259.0
#
#             new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# date
# 2020-01-30                 NaN           NaN         NaN                  NaN
# 2020-01-31                 NaN           NaN         NaN                  NaN
# 2020-02-01                 NaN           NaN         NaN                  NaN
# 2020-02-02                 NaN           NaN         NaN                  NaN
# 2020-02-03                 NaN           NaN         NaN                  NaN
# ...                        ...           ...         ...                  ...
# 2022-05-15            2628.571      524241.0        27.0               21.143
# 2022-05-16            2525.857      524260.0        19.0               22.429
# 2022-05-17            2373.286      524293.0        33.0               19.429
# 2022-05-18            2307.143      524303.0        10.0               17.429
# 2022-05-19            2224.000      524323.0        20.0               19.000
#
#             ...  female_smokers  male_smokers  handwashing_facilities  \
# date        ...
# 2020-01-30  ...             1.9          20.6                   59.55
# 2020-01-31  ...             1.9          20.6                   59.55
# 2020-02-01  ...             1.9          20.6                   59.55
# 2020-02-02  ...             1.9          20.6                   59.55
# 2020-02-03  ...             1.9          20.6                   59.55
# ...         ...             ...           ...                     ...
# 2022-05-15  ...             1.9          20.6                   59.55
# 2022-05-16  ...             1.9          20.6                   59.55
# 2022-05-17  ...             1.9          20.6                   59.55
# 2022-05-18  ...             1.9          20.6                   59.55
# 2022-05-19  ...             1.9          20.6                   59.55
#
#             hospital_beds_per_thousand  life_expectancy  \
# date
# 2020-01-30                        0.53            69.66
# 2020-01-31                        0.53            69.66
# 2020-02-01                        0.53            69.66
# 2020-02-02                        0.53            69.66
# 2020-02-03                        0.53            69.66
# ...                                ...              ...
# 2022-05-15                        0.53            69.66
# 2022-05-16                        0.53            69.66
# 2022-05-17                        0.53            69.66
# 2022-05-18                        0.53            69.66
# 2022-05-19                        0.53            69.66
#
#             human_development_index  excess_mortality_cumulative_absolute  \
# date
# 2020-01-30                    0.645                                   NaN
# 2020-01-31                    0.645                                   NaN
# 2020-02-01                    0.645                                   NaN
# 2020-02-02                    0.645                                   NaN
# 2020-02-03                    0.645                                   NaN
# ...                             ...                                   ...
# 2022-05-15                    0.645                                   NaN
# 2022-05-16                    0.645                                   NaN
# 2022-05-17                    0.645                                   NaN
# 2022-05-18                    0.645                                   NaN
# 2022-05-19                    0.645                                   NaN
#
#             excess_mortality_cumulative  excess_mortality  \
# date
# 2020-01-30                          NaN               NaN
# 2020-01-31                          NaN               NaN
# 2020-02-01                          NaN               NaN
# 2020-02-02                          NaN               NaN
# 2020-02-03                          NaN               NaN
# ...                                 ...               ...
# 2022-05-15                          NaN               NaN
# 2022-05-16                          NaN               NaN
# 2022-05-17                          NaN               NaN
# 2022-05-18                          NaN               NaN
# 2022-05-19                          NaN               NaN
#
#             excess_mortality_cumulative_per_million
# date
# 2020-01-30                                      NaN
# 2020-01-31                                      NaN
# 2020-02-01                                      NaN
# 2020-02-02                                      NaN
# 2020-02-03                                      NaN
# ...                                             ...
# 2022-05-15                                      NaN
# 2022-05-16                                      NaN
# 2022-05-17                                      NaN
# 2022-05-18                                      NaN
# 2022-05-19                                      NaN
#
# [841 rows x 67 columns]

# %% [markdown]
# Let's choose the fields 'new_cases', 'new_cases_smoothed' for forecasting. First of all, we should visualize this data.

# %%
import matplotlib.pyplot as plt
fields = ['new_cases', 'new_cases_smoothed']
c_covid[fields].plot()
plt.show()

# %% [markdown]
# ### Elimination of missing data

# %% [markdown]
# As you can see, there are large fluctuations in the new cases plot. Let's try to make a forecast for these waves.
# First of all, we should delete missing data using **pandas.DataFrame.dropna()**

# %%
c_covid = c_covid[fields].dropna()
c_covid
# Out:
#             new_cases  new_cases_smoothed
# date
# 2020-02-04        0.0               0.429
# 2020-02-05        0.0               0.429
# 2020-02-06        0.0               0.286
# 2020-02-07        0.0               0.286
# 2020-02-08        0.0               0.286
# ...               ...                 ...
# 2022-05-15     2202.0            2628.571
# 2022-05-16     1569.0            2525.857
# 2022-05-17     1829.0            2373.286
# 2022-05-18     2364.0            2307.143
# 2022-05-19     2259.0            2224.000
#
# [836 rows x 2 columns]

# %% [markdown]
# ### Data transformation

# %% [markdown]
#  To check for dependencies, it is necessary to perform a correlation analysis between them. This requires:
#
# 1.  duplicating of data and moving it vertically down for a certain number of days (lag)
# 2.  deleting the missing data at the beginning and end **pandas.DataFrame.shift()**
# 3.  calculating the correlation coefficient between the obtained series.
#
# It is convenient to create a separate function for lag:

# %%
def lag_correlation_ts(y, x, lag):
    """
   
    y: fixed
    x: shifted
    lag: lag for shifting
    r: DataFrame of lags correlation coefficients
    """
    r = [0] * (lag + 1)
    y = y.copy()
    x = x.copy()
    y.name = "y"
    x.name = "x"

    for i in range(0, lag + 1):
        ds = y.copy().to_frame()
        ds = ds.join(x.shift(i), how='outer')
        r[i] = ds.corr().values[0][1]
    r = pd.DataFrame(r)
    r.index.names = ['Lag']
    r.columns = ['Correlation']
    return r

# %% [markdown]
# Let's create a target DataSet.

# %%
y_dataset = c_covid['new_cases']
y_dataset
# Out:
# date
# 2020-02-04       0.0
# 2020-02-05       0.0
# 2020-02-06       0.0
# 2020-02-07       0.0
# 2020-02-08       0.0
#                ...
# 2022-05-15    2202.0
# 2022-05-16    1569.0
# 2022-05-17    1829.0
# 2022-05-18    2364.0
# 2022-05-19    2259.0
# Name: new_cases, Length: 836, dtype: float64

# %% [markdown]
# Let's test a 50-day lag.

# %%
pd.options.display.float_format = '{:,.4f}'.format
l = pd.DataFrame(lag_correlation_ts(y_dataset, y_dataset, 50)) 
print(l)
l.plot()
# Out:
#      Correlation
# Lag
# 0         1.0000
# 1         0.9947
# 2         0.9867
# 3         0.9783
# 4         0.9680
# 5         0.9562
# 6         0.9440
# 7         0.9289
# 8         0.9065
# 9         0.8820
# 10        0.8580
# 11        0.8334
# 12        0.8080
# 13        0.7834
# 14        0.7566
# 15        0.7248
# 16        0.6928
# 17        0.6625
# 18        0.6325
# 19        0.6030
# 20        0.5753
# 21        0.5471
# 22        0.5156
# 23        0.4851
# 24        0.4572
# 25        0.4302
# 26        0.4044
# 27        0.3805
# 28        0.3567
# 29        0.3309
# 30        0.3062
# 31        0.2839
# 32        0.2625
# 33        0.2422
# 34        0.2235
# 35        0.2051
# 36        0.1847
# 37        0.1656
# 38        0.1484
# 39        0.1318
# 40        0.1162
# 41        0.1023
# 42        0.0884
# 43        0.0728
# 44        0.0583
# 45        0.0453
# 46        0.0330
# 47        0.0212
# 48        0.0110
# 49        0.0008
# 50       -0.0110
# <AxesSubplot:xlabel='Lag'>

# %% [markdown]
# To automate this process, let's make a universal function for time series transformation to create this DataSet.

# %%
def series_to_supervised(in_data, tar_data, n_in=1, dropnan=True, target_dep=False):

    n_vars = in_data.shape[1]
    cols, names = list(), list()

    if target_dep:
        i_start = 1
    else:
        i_start = 0
    for i in range(i_start, n_in + 1):
        cols.append(in_data.shift(i))
        names += [('%s(t-%d)' % (in_data.columns[j], i)) for j in range(n_vars)]

    if target_dep:
        for i in range(n_in, -1, -1):
            cols.append(tar_data.shift(i))
            names += [('%s(t-%d)' % (tar_data.name, i))]
    else:
        # put it all together
        cols.append(tar_data)
        names.append(tar_data.name)
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)

    return agg

# %% [markdown]
#  When forecasting time series, the input and output fields are the same, only shifted by the lag.

# %%
dataset = series_to_supervised(pd.DataFrame(y_dataset), y_dataset, 14)
dataset
# Out:
#             new_cases(t-0)  new_cases(t-1)  new_cases(t-2)  new_cases(t-3)  \
# date
# 2020-02-18          0.0000          0.0000          0.0000          0.0000
# 2020-02-19          0.0000          0.0000          0.0000          0.0000
# 2020-02-20          0.0000          0.0000          0.0000          0.0000
# 2020-02-21          0.0000          0.0000          0.0000          0.0000
# 2020-02-22          0.0000          0.0000          0.0000          0.0000
# ...                    ...             ...             ...             ...
# 2022-05-15      2,202.0000      2,487.0000      2,858.0000      2,841.0000
# 2022-05-16      1,569.0000      2,202.0000      2,487.0000      2,858.0000
# 2022-05-17      1,829.0000      1,569.0000      2,202.0000      2,487.0000
# 2022-05-18      2,364.0000      1,829.0000      1,569.0000      2,202.0000
# 2022-05-19      2,259.0000      2,364.0000      1,829.0000      1,569.0000
#
#             new_cases(t-4)  new_cases(t-5)  new_cases(t-6)  new_cases(t-7)  \
# date
# 2020-02-18          0.0000          0.0000          0.0000          0.0000
# 2020-02-19          0.0000          0.0000          0.0000          0.0000
# 2020-02-20          0.0000          0.0000          0.0000          0.0000
# 2020-02-21          0.0000          0.0000          0.0000          0.0000
# 2020-02-22          0.0000          0.0000          0.0000          0.0000
# ...                    ...             ...             ...             ...
# 2022-05-15      2,827.0000      2,897.0000      2,288.0000      3,207.0000
# 2022-05-16      2,841.0000      2,827.0000      2,897.0000      2,288.0000
# 2022-05-17      2,858.0000      2,841.0000      2,827.0000      2,897.0000
# 2022-05-18      2,487.0000      2,858.0000      2,841.0000      2,827.0000
# 2022-05-19      2,202.0000      2,487.0000      2,858.0000      2,841.0000
#
#             new_cases(t-8)  new_cases(t-9)  new_cases(t-10)  new_cases(t-11)  \
# date
# 2020-02-18          0.0000          0.0000           0.0000           0.0000
# 2020-02-19          0.0000          0.0000           0.0000           0.0000
# 2020-02-20          0.0000          0.0000           0.0000           0.0000
# 2020-02-21          0.0000          0.0000           0.0000           0.0000
# 2020-02-22          0.0000          0.0000           0.0000           0.0000
# ...                    ...             ...              ...              ...
# 2022-05-15      3,451.0000      3,805.0000       3,545.0000       3,275.0000
# 2022-05-16      3,207.0000      3,451.0000       3,805.0000       3,545.0000
# 2022-05-17      2,288.0000      3,207.0000       3,451.0000       3,805.0000
# 2022-05-18      2,897.0000      2,288.0000       3,207.0000       3,451.0000
# 2022-05-19      2,827.0000      2,897.0000       2,288.0000       3,207.0000
#
#             new_cases(t-12)  new_cases(t-13)  new_cases(t-14)  new_cases
# date
# 2020-02-18           0.0000           0.0000           0.0000     0.0000
# 2020-02-19           0.0000           0.0000           0.0000     0.0000
# 2020-02-20           0.0000           0.0000           0.0000     0.0000
# 2020-02-21           0.0000           0.0000           0.0000     0.0000
# 2020-02-22           0.0000           0.0000           0.0000     0.0000
# ...                     ...              ...              ...        ...
# 2022-05-15       3,205.0000       2,568.0000       3,157.0000 2,202.0000
# 2022-05-16       3,275.0000       3,205.0000       2,568.0000 1,569.0000
# 2022-05-17       3,545.0000       3,275.0000       3,205.0000 1,829.0000
# 2022-05-18       3,805.0000       3,545.0000       3,275.0000 2,364.0000
# 2022-05-19       3,451.0000       3,805.0000       3,545.0000 2,259.0000
#
# [822 rows x 16 columns]

# %% [markdown]
# As you can see, the first and last columns contain the same target data.
# Now we should create input (**X**) and output (**Y**) .

# %%
col = dataset.columns
X, Y = dataset[col[1:-1]], dataset[col[-1]]
print("Input: ", X.columns)
print("Target:", Y.name)
# Out:
# Input:  Index(['new_cases(t-1)', 'new_cases(t-2)', 'new_cases(t-3)', 'new_cases(t-4)',
#        'new_cases(t-5)', 'new_cases(t-6)', 'new_cases(t-7)', 'new_cases(t-8)',
#        'new_cases(t-9)', 'new_cases(t-10)', 'new_cases(t-11)',
#        'new_cases(t-12)', 'new_cases(t-13)', 'new_cases(t-14)'],
#       dtype='object')
# Target: new_cases

# %% [markdown]
# ### Data normalization

# %% [markdown]
# After that, we should normalize all the data. To do this, the **sklearn.preprocessing.MinMaxScaler** module should be used.
# It allows us to normalize **fit_transform()** and convert back all the data easily: **inverse_transform()**.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_x = MinMaxScaler(feature_range=(0, 1))
scaler_y = MinMaxScaler(feature_range=(0, 1))

scaled_x = scaler_x.fit_transform(X)
scaled_y = scaler_y.fit_transform(Y.values.reshape(-1, 1))

# %% [markdown]
# After that, we are going to form training and test DataSets using **sklearn.model_selection.train_test_split()**.
#
# We will make them at the ratio of 73/27. Without shuffling. It means, that test samples are located in the end of **X** and **Y** DataSets.
#
# Input normalized DataSets: **X_train, X_test**
#
# Target normalized DataSets: **y_train, y_test**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(scaled_x, scaled_y, test_size=0.32, shuffle=False)

# %% [markdown]
# All the data is normalized now. However, in order to compare to results, we need real scale data of the training and test DataSet:

# %%
res_train = scaler_y.inverse_transform(y_train).flatten()
res_test = scaler_y.inverse_transform(y_test).flatten()

# %% [markdown]
# Target real scale DataSets: **res_train, res_test**.

# %% [markdown]
# # Linear Regression

# %% [markdown]
# First of all, we should create a model. We will test three type of models. A Linear regression, a Multilayer Neural Network with Backpropagation and a Long Short-Term Memory Neural Network.
# Let's create a **LinearRegression()**

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %% [markdown]
# After that, our model should be fitted on the training DataSet. Regardless of the model type, the function fit() is used to do this.

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Then we can test it on the test DataSet and use it for prognostication.

# %%
y_pred_test_ln = regressor.predict(X_test)
y_pred_test_ln = scaler_y.inverse_transform(y_pred_test_ln).flatten()

# %% [markdown]
# Let's analyze the results accuracy using **sklearn.metrics**.

# %%
from sklearn import metrics
print("Correlation train", regressor.score(X_train, y_train))
print("Correlation test", regressor.score(X_test, y_test))
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_test_ln))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_test_ln))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_test_ln)))
# Out:
# Correlation train 0.9966993360861955
# Correlation test 0.9887010809896141
# Mean Absolute Error: 39825.00426717726
# Mean Squared Error: 7272313854.298441
# Root Mean Squared Error: 85277.8626274043

# %% [markdown]
# # Back Propagation NN

# %% [markdown]
# The modern approach to the establishment of complex functional dependencies is the use of neural networks. A classical neural network is a **multilayer neural network with back propagation**.
#
# To do this, we will use the **keras** framework.
# First of all, we should create a Neural Network model as a separate function.
#
# A neural network is a sequence of layers. The function **Sequential()** is used to create a network.
#
# Let's create a network that consists of 2 hidden layers. Each of which consists of 100 neurons. **keras.layers.Dense()**.
#
# To avoid retraining problems, we will use additional layers **keras.layers.Dropout()**.
#
# The output layer will consist of one neuron, since we have only one value at the output.
#
# The model should be compiled for fitting and predicting: **keras.Model.compile()**.

# %%
def BP_model(X):
    """
    Multilayer neural network with back propagation.
    X: Input DataSet
    return: keras NN model
    """
    # create model
    model = Sequential() 
    model.add(Dense(100, input_dim=X.shape[1], kernel_initializer='normal', activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(100, kernel_initializer='normal', activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1, kernel_initializer='normal'))
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %% [markdown]
# Once the model function is built, it is necessary to create a neural network directly and specify the learning parameters: **keras.wrappers.scikit_learn.KerasRegressor()**.
#
# Also we should define the number of fitting **epoch and batch size**.

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
epochs = 1000

batch_size=int(y_train.shape[0]*.1)

estimator = KerasRegressor(build_fn=BP_model, X=X_train, epochs=epochs, batch_size=batch_size, verbose=1)

# %% [markdown]
# Now, let’s train our model for **1000** epochs.
# It should be noted that the fitting process is very slow. Therefore, we saved our fitted model to a file.
# To save time, we will upload the fitted model.
# If you like, you can leave the parameter **fitting on True** to refit the model.
# If you like, you can leave the parameter **fitting_save on True** to resave the model.

# %%
fitting = True
fitting_save = True

import pickle

if fitting:
    history=estimator.fit(X_train,y_train, validation_data=(X_test,y_test)) # Fitting model
    if fitting_save:
        # Save model
        estimator.model.save('BP_saved_model.h5')
        print("Saved model to disk")
        with open('history.pickle', 'wb') as f:
            pickle.dump(history.history, f)
# load model 
from keras.models import load_model
estimator = KerasRegressor(build_fn=BP_model, X=X_train, epochs=epochs, batch_size=batch_size, verbose=1)
estimator.model = load_model('BP_saved_model.h5')    
with open('history.pickle', 'rb') as f:
    history = pickle.load(f)
print("Loaded model from disk")
# Out:
# User settings:
#
#    KMP_AFFINITY=granularity=fine,noverbose,compact,1,0
#    KMP_BLOCKTIME=0
#    KMP_DUPLICATE_LIB_OK=True
#    KMP_INIT_AT_FORK=FALSE
#    KMP_SETTINGS=1
#    KMP_WARNINGS=0
#
# Effective settings:
#
#    KMP_ABORT_DELAY=0
#    KMP_ADAPTIVE_LOCK_PROPS='1,1024'
#    KMP_ALIGN_ALLOC=64
#    KMP_ALL_THREADPRIVATE=128
#    KMP_ATOMIC_MODE=2
#    KMP_BLOCKTIME=0
#    KMP_CPUINFO_FILE: value is not defined
#    KMP_DETERMINISTIC_REDUCTION=false
#    KMP_DEVICE_THREAD_LIMIT=2147483647
#    KMP_DISP_NUM_BUFFERS=7
#    KMP_DUPLICATE_LIB_OK=true
#    KMP_ENABLE_TASK_THROTTLING=true
#    KMP_FORCE_REDUCTION: value is not defined
#    KMP_FOREIGN_THREADS_THREADPRIVATE=true
#    KMP_FORKJOIN_BARRIER='2,2'
#    KMP_FORKJOIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_GTID_MODE=3
#    KMP_HANDLE_SIGNALS=false
#    KMP_HOT_TEAMS_MAX_LEVEL=1
#    KMP_HOT_TEAMS_MODE=0
#    KMP_INIT_AT_FORK=true
#    KMP_LIBRARY=throughput
#    KMP_LOCK_KIND=queuing
#    KMP_MALLOC_POOL_INCR=1M
#    KMP_NUM_LOCKS_IN_BLOCK=1
#    KMP_PLAIN_BARRIER='2,2'
#    KMP_PLAIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_REDUCTION_BARRIER='1,1'
#    KMP_REDUCTION_BARRIER_PATTERN='hyper,hyper'
#    KMP_SCHEDULE='static,balanced;guided,iterative'
#    KMP_SETTINGS=true
#    KMP_SPIN_BACKOFF_PARAMS='4096,100'
#    KMP_STACKOFFSET=64
#    KMP_STACKPAD=0
#    KMP_STACKSIZE=8M
#    KMP_STORAGE_MAP=false
#    KMP_TASKING=2
#    KMP_TASKLOOP_MIN_TASKS=0
#    KMP_TASK_STEALING_CONSTRAINT=1
#    KMP_TEAMS_THREAD_LIMIT=4
#    KMP_TOPOLOGY_METHOD=all
#    KMP_USE_YIELD=1
#    KMP_VERSION=false
#    KMP_WARNINGS=false
#    OMP_AFFINITY_FORMAT='OMP: pid %P tid %i thread %n bound to OS proc set {%A}'
#    OMP_ALLOCATOR=omp_default_mem_alloc
#    OMP_CANCELLATION=false
#    OMP_DEFAULT_DEVICE=0
#    OMP_DISPLAY_AFFINITY=false
#    OMP_DISPLAY_ENV=false
#    OMP_DYNAMIC=false
#    OMP_MAX_ACTIVE_LEVELS=1
#    OMP_MAX_TASK_PRIORITY=0
#    OMP_NESTED: deprecated; max-active-levels-var=1
#    OMP_NUM_THREADS: value is not defined
#    OMP_PLACES: value is not defined
#    OMP_PROC_BIND='intel'
#    OMP_SCHEDULE='static'
#    OMP_STACKSIZE=8M
#    OMP_TARGET_OFFLOAD=DEFAULT
#    OMP_THREAD_LIMIT=2147483647
#    OMP_WAIT_POLICY=PASSIVE
#    KMP_AFFINITY='noverbose,warnings,respect,granularity=fine,compact,1,0'
#
# 2022-05-20 15:01:49.358140: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2022-05-20 15:01:49.526904: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/1000
# 11/11 [==============================] - 1s 20ms/step - loss: 0.0420 - val_loss: 0.0176
# Epoch 2/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0121 - val_loss: 0.0115
# Epoch 3/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.0069
# Epoch 4/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0060
# Epoch 5/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0048
# Epoch 6/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0030 - val_loss: 0.0041
# Epoch 7/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0033
# Epoch 8/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 9/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 10/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 11/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 12/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 13/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 14/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 15/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 16/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 17/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 18/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 19/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 20/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 21/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 22/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 9.0968e-04 - val_loss: 0.0011
# Epoch 23/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 24/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 25/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 26/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 27/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 8.7048e-04
# Epoch 28/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 8.5972e-04
# Epoch 29/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 9.8230e-04
# Epoch 30/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 9.5807e-04 - val_loss: 8.8294e-04
# Epoch 31/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 32/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 8.9560e-04
# Epoch 33/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 8.5998e-04
# Epoch 34/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 35/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 9.2543e-04
# Epoch 36/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 8.2324e-04
# Epoch 37/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 8.4671e-04
# Epoch 38/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 9.5741e-04 - val_loss: 8.1922e-04
# Epoch 39/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 40/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 8.2303e-04 - val_loss: 8.6633e-04
# Epoch 41/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 42/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 9.7309e-04 - val_loss: 7.4102e-04
# Epoch 43/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 7.1438e-04
# Epoch 44/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 45/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 9.9378e-04 - val_loss: 7.6582e-04
# Epoch 46/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 7.6831e-04
# Epoch 47/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 48/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 7.8902e-04 - val_loss: 9.4752e-04
# Epoch 49/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 9.3473e-04 - val_loss: 7.5265e-04
# Epoch 50/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 51/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 9.2680e-04 - val_loss: 7.0768e-04
# Epoch 52/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 7.7581e-04
# Epoch 53/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 7.9153e-04
# Epoch 54/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 9.6469e-04 - val_loss: 0.0012
# Epoch 55/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 9.6491e-04 - val_loss: 8.3383e-04
# Epoch 56/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 9.0051e-04 - val_loss: 8.3756e-04
# Epoch 57/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 9.1506e-04 - val_loss: 7.1791e-04
# Epoch 58/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 9.7816e-04 - val_loss: 0.0015
# Epoch 59/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 9.3533e-04 - val_loss: 7.9114e-04
# Epoch 60/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 8.3589e-04 - val_loss: 8.7908e-04
# Epoch 61/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 9.7877e-04 - val_loss: 0.0011
# Epoch 62/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 7.4982e-04 - val_loss: 6.8355e-04
# Epoch 63/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 8.9010e-04 - val_loss: 0.0011
# Epoch 64/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 9.6988e-04
# Epoch 65/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 7.0956e-04 - val_loss: 7.9079e-04
# Epoch 66/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 7.2582e-04
# Epoch 67/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 6.1146e-04
# Epoch 68/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 69/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 7.9659e-04
# Epoch 70/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 9.4073e-04 - val_loss: 6.8791e-04
# Epoch 71/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 9.8483e-04 - val_loss: 7.2204e-04
# Epoch 72/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 9.6548e-04 - val_loss: 7.2127e-04
# Epoch 73/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.0246e-04 - val_loss: 9.4733e-04
# Epoch 74/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 7.3863e-04 - val_loss: 8.7690e-04
# Epoch 75/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.6127e-04 - val_loss: 6.4809e-04
# Epoch 76/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 8.3239e-04 - val_loss: 6.4995e-04
# Epoch 77/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 9.9913e-04 - val_loss: 6.6116e-04
# Epoch 78/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 79/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 9.7725e-04 - val_loss: 6.5550e-04
# Epoch 80/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.8829e-04 - val_loss: 9.2249e-04
# Epoch 81/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.1715e-04 - val_loss: 7.3585e-04
# Epoch 82/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.0376e-04 - val_loss: 0.0012
# Epoch 83/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 7.5669e-04 - val_loss: 8.5742e-04
# Epoch 84/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 9
1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.5304e-04 - val_loss: 7.1737e-04
# Epoch 889/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.5650e-04 - val_loss: 5.4467e-04
# Epoch 890/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.6043e-04 - val_loss: 7.0113e-04
# Epoch 891/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.6987e-04 - val_loss: 6.9723e-04
# Epoch 892/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 7.5435e-04 - val_loss: 0.0014
# Epoch 893/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 8.7986e-04 - val_loss: 8.5309e-04
# Epoch 894/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 7.0366e-04
# Epoch 895/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 896/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.1839e-04 - val_loss: 9.5189e-04
# Epoch 897/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.8209e-04 - val_loss: 5.6502e-04
# Epoch 898/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.6577e-04 - val_loss: 0.0010
# Epoch 899/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 7.8686e-04 - val_loss: 0.0017
# Epoch 900/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 7.2527e-04
# Epoch 901/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 8.9399e-04 - val_loss: 8.7925e-04
# Epoch 902/1000
# 11/11 [==============================] - 0s 13ms/step - loss: 6.3298e-04 - val_loss: 9.9139e-04
# Epoch 903/1000
# 11/11 [==============================] - 0s 21ms/step - loss: 6.1203e-04 - val_loss: 8.1172e-04
# Epoch 904/1000
# 11/11 [==============================] - 0s 23ms/step - loss: 5.2461e-04 - val_loss: 0.0013
# Epoch 905/1000
# 11/11 [==============================] - 0s 26ms/step - loss: 7.5392e-04 - val_loss: 6.7893e-04
# Epoch 906/1000
# 11/11 [==============================] - 0s 19ms/step - loss: 6.8737e-04 - val_loss: 0.0011
# Epoch 907/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.3716e-04 - val_loss: 0.0011
# Epoch 908/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.7274e-04 - val_loss: 5.0607e-04
# Epoch 909/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.8424e-04 - val_loss: 7.2375e-04
# Epoch 910/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.9689e-04 - val_loss: 0.0010
# Epoch 911/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.6524e-04 - val_loss: 6.0587e-04
# Epoch 912/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.4721e-04 - val_loss: 8.4905e-04
# Epoch 913/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.1022e-04 - val_loss: 6.5020e-04
# Epoch 914/1000
# 11/11 [==============================] - 0s 5ms/step - loss: 4.3105e-04 - val_loss: 7.7883e-04
# Epoch 915/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.6419e-04 - val_loss: 5.8674e-04
# Epoch 916/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.9708e-04 - val_loss: 0.0013
# Epoch 917/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.0871e-04 - val_loss: 6.9700e-04
# Epoch 918/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 4.3186e-04 - val_loss: 8.0851e-04
# Epoch 919/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.8228e-04 - val_loss: 0.0011
# Epoch 920/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 7.6257e-04 - val_loss: 5.1983e-04
# Epoch 921/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.4394e-04 - val_loss: 6.5947e-04
# Epoch 922/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.0243e-04 - val_loss: 6.2380e-04
# Epoch 923/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.4007e-04 - val_loss: 9.4293e-04
# Epoch 924/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.4899e-04 - val_loss: 8.4430e-04
# Epoch 925/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.6472e-04 - val_loss: 6.4114e-04
# Epoch 926/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.6655e-04 - val_loss: 9.0156e-04
# Epoch 927/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.9649e-04 - val_loss: 7.1854e-04
# Epoch 928/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 7.2756e-04 - val_loss: 0.0011
# Epoch 929/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.5509e-04 - val_loss: 4.8836e-04
# Epoch 930/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.3940e-04 - val_loss: 7.2766e-04
# Epoch 931/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.3904e-04 - val_loss: 8.6480e-04
# Epoch 932/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.8535e-04 - val_loss: 5.4600e-04
# Epoch 933/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.2114e-04 - val_loss: 8.2988e-04
# Epoch 934/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.6573e-04 - val_loss: 4.9656e-04
# Epoch 935/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.0903e-04 - val_loss: 0.0012
# Epoch 936/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.9796e-04 - val_loss: 5.3443e-04
# Epoch 937/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 8.5645e-04 - val_loss: 0.0014
# Epoch 938/1000
# 11/11 [==============================] - 0s 5ms/step - loss: 8.6363e-04 - val_loss: 8.6130e-04
# Epoch 939/1000
# 11/11 [==============================] - 0s 5ms/step - loss:
1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.5223e-04 - val_loss: 0.0011
# Epoch 990/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.0895e-04 - val_loss: 6.0479e-04
# Epoch 991/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.2396e-04 - val_loss: 9.6866e-04
# Epoch 992/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 5.9111e-04 - val_loss: 5.3508e-04
# Epoch 993/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.3604e-04 - val_loss: 6.8913e-04
# Epoch 994/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.5230e-04 - val_loss: 8.1728e-04
# Epoch 995/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.8440e-04 - val_loss: 7.7980e-04
# Epoch 996/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 3.6537e-04 - val_loss: 7.4126e-04
# Epoch 997/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.5135e-04 - val_loss: 7.2238e-04
# Epoch 998/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.2667e-04 - val_loss: 7.7536e-04
# Epoch 999/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 4.3388e-04 - val_loss: 8.6688e-04
# Epoch 1000/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 6.6054e-04 - val_loss: 0.0012
# Saved model to disk
# Loaded model from disk

# %%
plt.figure()
plt.plot(history['loss'], label='train')
plt.plot(history['val_loss'], label='test')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.show()

# %% [markdown]
# As you can see, a Neural Network is well-fitted and no overfitting is observed.
# Let's calculate a prediction of the training (**res_train_ANN**) an test (**res_test_ANN**) sets.

# %% [markdown]
# Let's calculate a forecast and make an inverse normalization to real scale.

# %%
res_tr=estimator.predict(X_train)
res_ts=estimator.predict(X_test)
res_train_ANN=scaler_y.inverse_transform(res_tr.reshape(-1, 1)).flatten()
res_test_ANN=scaler_y.inverse_transform(res_ts.reshape(-1, 1)).flatten()
# Out:
# 11/11 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 2ms/step

# %% [markdown]
# Let's compare the accuracy of a Linear Regression and a Neural Network.

# %%
print("Correlation train", np.corrcoef(res_train, res_train_ANN)[0,1])
print("Correlation train", np.corrcoef(res_test, res_test_ANN)[0,1])
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, res_test_ANN))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, res_test_ANN))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, res_test_ANN)))
# Out:
# Correlation train 0.9984408072051532
# Correlation train 0.9919125346304628
# Mean Absolute Error: 45188.805803863914
# Mean Squared Error: 8919141897.366425
# Root Mean Squared Error: 94441.20868226129

# %% [markdown]
# We got slightly better results for a Neural Network than for a Linear Regression.

# %% [markdown]
# # Long Short-Term Memory - LSTM

# %% [markdown]
# Unlike standard feedforward neural networks, **LSTM** has feedback connections. It can process not only single data points, but also entire sequences of data (such as speech, video or time series).
#
# In case of time series, the neural network has one input and one output. However, there should be a vector of time series values for the previous time period on the input.

# %% [markdown]
# To do this, we should transform input DataSets into 3D shape.

# %%
train_x_LSTM = X_train.reshape((X_train.shape[0], 1, 14))
test_x_LSTM = X_test.reshape((X_test.shape[0], 1, 14))

# %% [markdown]
# Let's create an LSTM Neural Network consisting of one **LSTM** layer and one BP layer like in the previous case.
# In this case our NN will consist of 7 LSTM and 7 BP neurons only.

# %%
from keras.layers import LSTM

batch_size=int(y_train.shape[0]*.1)
model = Sequential()
model.add(LSTM(7, input_shape=(train_x_LSTM.shape[1], train_x_LSTM.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(7, kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(y_train.shape[1])) #activation='sigmoid'
model.compile(loss='mean_squared_error', optimizer='adam')

# %% [markdown]
# All subsequent steps of learning, storing, reading and predicting are similar to the ones we used with the previous neural network. You can see that only 420 epochs are enough for an LSTM.

# %%
fitting = True
fitting_save = True
epochs = 420

if fitting:
    history = model.fit(train_x_LSTM, y_train, epochs=epochs, batch_size=batch_size, validation_data=(test_x_LSTM, y_test), verbose=1, shuffle=False)    
    if fitting_save:
    # serialize model to JSON
        model_json = model.to_json()
        with open("LSTM_model.json", "w") as json_file:
            json_file.write(model_json)
        # serialize weights to HDF5
        model.save_weights("LSTM_model.h5")
        print("Saved model to disk")
        with open('history_LSTM.pickle', 'wb') as f:
            pickle.dump(history.history, f)
# load model  
from keras.models import model_from_json
json_file = open('LSTM_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)
# load weights into new model
model.load_weights("LSTM_model.h5")        
with open('history_LSTM.pickle', 'rb') as f:
    history = pickle.load(f)
print("Loaded model from disk")
# Out:
# Epoch 1/420
# 11/11 [==============================] - 3s 52ms/step - loss: 0.0555 - val_loss: 0.0367
# Epoch 2/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0493 - val_loss: 0.0329
# Epoch 3/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0437 - val_loss: 0.0303
# Epoch 4/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0399 - val_loss: 0.0287
# Epoch 5/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0352 - val_loss: 0.0276
# Epoch 6/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0347 - val_loss: 0.0265
# Epoch 7/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0328 - val_loss: 0.0254
# Epoch 8/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0306 - val_loss: 0.0242
# Epoch 9/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0278 - val_loss: 0.0227
# Epoch 10/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0253 - val_loss: 0.0211
# Epoch 11/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0243 - val_loss: 0.0193
# Epoch 12/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0210 - val_loss: 0.0175
# Epoch 13/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0181 - val_loss: 0.0157
# Epoch 14/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0164 - val_loss: 0.0138
# Epoch 15/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0139 - val_loss: 0.0122
# Epoch 16/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0153 - val_loss: 0.0107
# Epoch 17/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0119 - val_loss: 0.0094
# Epoch 18/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0093 - val_loss: 0.0084
# Epoch 19/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0117 - val_loss: 0.0077
# Epoch 20/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0083 - val_loss: 0.0071
# Epoch 21/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0083 - val_loss: 0.0067
# Epoch 22/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0099 - val_loss: 0.0064
# Epoch 23/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0081 - val_loss: 0.0062
# Epoch 24/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0078 - val_loss: 0.0059
# Epoch 25/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0058
# Epoch 26/420
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0078 - val_loss: 0.0057
# Epoch 27/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0059 - val_loss: 0.0056
# Epoch 28/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0078 - val_loss: 0.0055
# Epoch 29/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0086 - val_loss: 0.0054
# Epoch 30/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0076 - val_loss: 0.0053
# Epoch 31/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0076 - val_loss: 0.0053
# Epoch 32/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0078 - val_loss: 0.0052
# Epoch 33/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0071 - val_loss: 0.0051
# Epoch 34/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0077 - val_loss: 0.0050
# Epoch 35/420
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0078 - val_loss: 0.0049
# Epoch 36/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0070 - val_loss: 0.0048
# Epoch 37/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0079 - val_loss: 0.0047
# Epoch 38/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0067 - val_loss: 0.0046
# Epoch 39/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.0045
# Epoch 40/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0059 - val_loss: 0.0044
# Epoch 41/420
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0064 - val_loss: 0.0043
# Epoch 42/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0062 - val_loss: 0.0043
# Epoch 43/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0042
# Epoch 44/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0069 - val_loss: 0.0042
# Epoch 45/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0068 - val_loss: 0.0041
# Epoch 46/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 0.0040
# Epoch 47/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0072 - val_loss: 0.0039
# Epoch 48/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.0038
# Epoch 49/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0064 - val_loss: 0.0037
# Epoch 50/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0073 - val_loss: 0.0037
# Epoch 51/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0055 - val_loss: 0.0036
# Epoch 52/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0055 - val_loss: 0.0035
# Epoch 53/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0068 - val_loss: 0.0035
# Epoch 54/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0034
# Epoch 55/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0067 - val_loss: 0.0034
# Epoch 56/420
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0052 - val_loss: 0.0034
# Epoch 57/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0070 - val_loss: 0.0033
# Epoch 58/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0052 - val_loss: 0.0032
# Epoch 59/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0069 - val_loss: 0.0031
# Epoch 60/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0060 - val_loss: 0.0030
# Epoch 61/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 0.0030
# Epoch 62/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0059 - val_loss: 0.0030
# Epoch 63/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0067 - val_loss: 0.0029
# Epoch 64/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.0029
# Epoch 65/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0028
# Epoch 66/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0061 - val_loss: 0.0028
# Epoch 67/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 0.0027
# Epoch 68/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0027
# Epoch 69/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0026
# Epoch 70/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0026
# Epoch 71/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0026
# Epoch 72/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0054 - val_loss: 0.0025
# Epoch 73/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0069 - val_loss: 0.0025
# Epoch 74/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0025
# Epoch 75/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0039 - val_loss: 0.0025
# Epoch 76/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0024
# Epoch 77/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0052 - val_loss: 0.0024
# Epoch 78/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0023
# Epoch 79/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0023
# Epoch 80/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 0.0023
# Epoch 81/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0051 - val_loss: 0.0023
# Epoch 82/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0023
# Epoch 83/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0062 - val_loss: 0.0023
# Epoch 84/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0023
# Epoch 85/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0038 - val_loss: 0.0022
# Epoch 86/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0048 - val_loss: 0.0022
# Epoch 87/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.0022
# Epoch 88/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.0022
# Epoch 89/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0022
# Epoch 90/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.0022
# Epoch 91/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0067 - val_loss: 0.0023
# Epoch 92/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0052 - val_loss: 0.0022
# Epoch 93/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0064 - val_loss: 0.0023
# Epoch 94/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0059 - val_loss: 0.0021
# Epoch 95/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0021
# Epoch 96/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 0.0021
# Epoch 97/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 0.0021
# Epoch 98/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0021
# Epoch 99/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0055 - val_loss: 0.0021
# Epoch 100/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0052 - val_loss: 0.0020
# Epoch 101/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0051 - val_loss: 0.0020
# Epoch 102/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0059 - val_loss: 0.0020
# Epoch 103/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0020
# Epoch 104/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0059 - val_loss: 0.0020
# Epoch 105/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0048 - val_loss: 0.0020
# Epoch 106/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0048 - val_loss: 0.0021
# Epoch 107/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0040 - val_loss: 0.0020
# Epoch 108/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0060 - val_loss: 0.0020
# Epoch 109/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 0.0020
# Epoch 110/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0020
# Epoch 111/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0056 - val_loss: 0.0020
# Epoch 112/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0044 - val_loss: 0.0020
# Epoch 113/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0051 - val_loss: 0.0020
# Epoch 114/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0020
# Epoch 115/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0020
# Epoch 116/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0019
# Epoch 117/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0019
# Epoch 118/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0051 - val_loss: 0.0019
# Epoch 119/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0061 - val_loss: 0.0020
# Epoch 120/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0020
# Epoch 121/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0051 - val_loss: 0.0019
# Epoch 122/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0019
# Epoch 123/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0054 - val_loss: 0.0019
# Epoch 124/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0020
# Epoch 125/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0035 - val_loss: 0.0019
# Epoch 126/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0019
# Epoch 127/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0018
# Epoch 128/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.0019
# Epoch 129/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 0.0018
# Epoch 130/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0018
# Epoch 131/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0052 - val_loss: 0.0018
# Epoch 132/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0018
# Epoch 133/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0048 - val_loss: 0.0018
# Epoch 134/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0039 - val_loss: 0.0019
# Epoch 135/420
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0042 - val_loss: 0.0018
# Epoch 136/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0062 - val_loss: 0.0018
# Epoch 137/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0018
# Epoch 138/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0051 - val_loss: 0.0018
# Epoch 139/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 0.0019
# Epoch 140/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0018
# Epoch 141/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0055 - val_loss: 0.0018
# Epoch 142/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0017
# Epoch 143/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 0.0017
# Epoch 144/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0048 - val_loss: 0.0017
# Epoch 145/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0038 - val_loss: 0.0018
# Epoch 146/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0059 - val_loss: 0.0018
# Epoch 147/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0037 - val_loss: 0.0019
# Epoch 148/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0019
# Epoch 149/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0051 - val_loss: 0.0018
# Epoch 150/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0018
# Epoch 151/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0051 - val_loss: 0.0018
# Epoch 152/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0019
# Epoch 153/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 0.0018
# Epoch 154/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0018
# Epoch 155/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0040 - val_loss: 0.0018
# Epoch 156/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0048 - val_loss: 0.0018
# Epoch 157/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0055 - val_loss: 0.0018
# Epoch 158/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0035 - val_loss: 0.0018
# Epoch 159/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 0.0018
# Epoch 160/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.0017
# Epoch 161/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0017
# Epoch 162/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0017
# Epoch 163/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0017
# Epoch 164/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0055 - val_loss: 0.0017
# Epoch 165/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0017
# Epoch 166/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0017
# Epoch 167/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0039 - val_loss: 0.0017
# Epoch 168/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0017
# Epoch 169/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0017
# Epoch 170/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0018
# Epoch 171/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0018
# Epoch 172/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0074 - val_loss: 0.0019
# Epoch 173/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0055 - val_loss: 0.0018
# Epoch 174/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0048 - val_loss: 0.0017
# Epoch 175/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0048 - val_loss: 0.0018
# Epoch 176/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0074 - val_loss: 0.0018
# Epoch 177/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0017
# Epoch 178/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0052 - val_loss: 0.0017
# Epoch 179/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0017
# Epoch 180/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0084 - val_loss: 0.0017
# Epoch 181/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0040 - val_loss: 0.0018
# Epoch 182/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0017
# Epoch 183/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0055 - val_loss: 0.0017
# Epoch 184/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0017
# Epoch 185/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0040 - val_loss: 0.0017
# Epoch 186/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0035 - val_loss: 0.0018
# Epoch 187/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0057 - val_loss: 0.0017
# Epoch 188/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0017
# Epoch 189/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0041 - val_loss: 0.0016
# Epoch 190/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0016
# Epoch 191/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0037 - val_loss: 0.0017
# Epoch 192/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0017
# Epoch 193/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0048 - val_loss: 0.0016
# Epoch 194/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0038 - val_loss: 0.0017
# Epoch 195/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0017
# Epoch 196/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0054 - val_loss: 0.0016
# Epoch 197/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0048 - val_loss: 0.0016
# Epoch 198/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0017
# Epoch 199/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0016
# Epoch 200/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0054 - val_loss: 0.0016
# Epoch 201/420
# 11/11 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.
420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0054 - val_loss: 0.0014
# Epoch 348/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0039 - val_loss: 0.0014
# Epoch 349/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0014
# Epoch 350/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0038 - val_loss: 0.0013
# Epoch 351/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0037 - val_loss: 0.0014
# Epoch 352/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 0.0015
# Epoch 353/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0055 - val_loss: 0.0014
# Epoch 354/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0013
# Epoch 355/420
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0044 - val_loss: 0.0013
# Epoch 356/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0013
# Epoch 357/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0013
# Epoch 358/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0014
# Epoch 359/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0037 - val_loss: 0.0014
# Epoch 360/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0014
# Epoch 361/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0054 - val_loss: 0.0014
# Epoch 362/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.0014
# Epoch 363/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0013
# Epoch 364/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0048 - val_loss: 0.0014
# Epoch 365/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0014
# Epoch 366/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0048 - val_loss: 0.0014
# Epoch 367/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 0.0015
# Epoch 368/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.0014
# Epoch 369/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0014
# Epoch 370/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0035 - val_loss: 0.0014
# Epoch 371/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 0.0014
# Epoch 372/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0052 - val_loss: 0.0014
# Epoch 373/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0013
# Epoch 374/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0054 - val_loss: 0.0013
# Epoch 375/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0039 - val_loss: 0.0013
# Epoch 376/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0014
# Epoch 377/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 378/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0013
# Epoch 379/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0013
# Epoch 380/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0035 - val_loss: 0.0013
# Epoch 381/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0013
# Epoch 382/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0013
# Epoch 383/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.0013
# Epoch 384/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0014
# Epoch 385/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.0014
# Epoch 386/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0014
# Epoch 387/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.0014
# Epoch 388/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0048 - val_loss: 0.0014
# Epoch 389/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0065 - val_loss: 0.0013
# Epoch 390/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0013
# Epoch 391/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0060 - val_loss: 0.0013
# Epoch 392/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0014
# Epoch 393/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0037 - val_loss: 0.0014
# Epoch 394/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0035 - val_loss: 0.0014
# Epoch 395/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0013
# Epoch 396/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0038 - val_loss: 0.0013
# Epoch 397/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0069 - val_loss: 0.0013
# Epoch 398/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0014
# Epoch 399/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0014
# Epoch 400/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 0.0013
# Epoch 401/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 0.0013
# Epoch 402/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 0.0014
# Epoch 403/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.0013
# Epoch 404/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0015
# Epoch 405/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 0.0014
# Epoch 406/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0037 - val_loss: 0.0014
# Epoch 407/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0055 - val_loss: 0.0014
# Epoch 408/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0013
# Epoch 409/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 0.0013
# Epoch 410/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0039 - val_loss: 0.0014
# Epoch 411/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0055 - val_loss: 0.0017
# Epoch 412/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0061 - val_loss: 0.0015
# Epoch 413/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0037 - val_loss: 0.0014
# Epoch 414/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0013
# Epoch 415/420
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 0.0013
# Epoch 416/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0038 - val_loss: 0.0013
# Epoch 417/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0037 - val_loss: 0.0014
# Epoch 418/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0013
# Epoch 419/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0051 - val_loss: 0.0013
# Epoch 420/420
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0013
# Saved model to disk
# Loaded model from disk

# %% [markdown]
# Let's plot the dynamic of loss and val loss like in the previous case.

# %%
plt.figure()
plt.plot(history['loss'], label='train')
plt.plot(history['val_loss'], label='test')
plt.ylabel('loss')
plt.xlabel('epoch')

plt.legend()
plt.show()

# %% [markdown]
# Let's calculate our forecast.

# %%
res_tr_LSTM = model.predict(train_x_LSTM)
res_ts_LSTM = model.predict(test_x_LSTM)
res_train_LSTM=scaler_y.inverse_transform(res_tr_LSTM).flatten()
res_test_LSTM=scaler_y.inverse_transform(res_ts_LSTM).flatten()

# %% [markdown]
# And accuracy:

# %%
print("Correlation train", np.corrcoef(res_train, res_train_LSTM)[0,1])
print("Correlation train", np.corrcoef(res_test, res_test_LSTM)[0,1])
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, res_test_LSTM))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, res_test_LSTM))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, res_test_LSTM)))
# Out:
# Correlation train 0.9952632919566066
# Correlation train 0.982904949241872
# Mean Absolute Error: 45799.107078019035
# Mean Squared Error: 7374498279.003543
# Root Mean Squared Error: 85874.89900432805

# %% [markdown]
# As you can see, the forecast results of the test data set are much better than ones of the previous models. Let's visualize these 3 results:

# %%
res_pred_test_ln = pd.Series(y_pred_test_ln, name = 'Predicted test Linear Model')
res_pred_test_ANN = pd.Series(res_test_ANN, name = 'Predicted test ANN')
res_pred_test_LSTM = pd.Series(res_test_LSTM, name = 'Predicted test LSTM')

df_2 = pd.DataFrame({'Actual test': res_test, 'Linear Model': res_pred_test_ln, 'ANN Model': res_pred_test_ANN,  'LSTM Model': res_pred_test_LSTM,})
df_2.index = dataset.index[len(dataset)-len(res_test):]
df_2.plot()
df_2 = pd.DataFrame({'Actual test': res_test, 'Linear Model': res_pred_test_ln,})
df_2.index = dataset.index[len(dataset)-len(res_test):]
df_2.plot()
df_2 = pd.DataFrame({'Actual test': res_test, 'LSTM Model': res_pred_test_LSTM,})
df_2.index = dataset.index[len(dataset)-len(res_test):]
df_2.plot()
df_2 = pd.DataFrame({'Actual test': res_test,'ANN Model': res_pred_test_ANN,})
df_2.index = dataset.index[len(dataset)-len(res_test):]
df_2.plot()
plt.show()

# %% [markdown]
# As you can see, an LSTM model makes a perfect forecast. A Linear Regression is the fastest forecasting model.
